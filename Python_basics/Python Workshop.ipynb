# %% [markdown]
# # Welcome All

# %%
3+5
# Out:
# 8

# %%
print("Hello World")
# Out:
# Hello World

# %%
import math

help(math)

math.sqrt(64)

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(...)
#     sqrt(x)
#
#     Return the square root of x.

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
dna = "ATG"

# %%
print(dna)
# Out:
# ATG

# %%
mass = 47.5
height = 24.5
age = 122
mass = mass * 2.3
age = age - 20
height = height + 20

# %%
print(mass)
print(age)
print(height)
# Out:
# 109.24999999999999
# 102
# 44.5

# %%
who
# Out:
# a	 age	 dna	 height	 mass

# %%
del(a)

# %%
who
# Out:
# age	 dna	 height	 mass

# %%
reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
who
# Out:
# Interactive namespace is empty.

# %%
help(math)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e606f19bc963> in <module>()
# ----> 1 help(math)
#
# NameError: name 'math' is not defined

# %%
import math

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
#         atan(x)
#
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(...)
#         atan2(y, x)
#
#         Return the arc tangent (measured in radians) of y/x.
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(...)
#         atanh(x)
#
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(...)
#         ceil(x)
#
# ...

# %%
a = 5.7

# %%
print(a)
# Out:
# 5.7

# %%
dna = "ATG"

# %%
print(dna)
# Out:
# ATG

# %%
type(a)
# Out:
# float

# %%
type(dna)
# Out:
# str

# %% [markdown]
# str() - to convert to string data type
#
# int() - to convert to integer data type
#
# float() - to convert to float data type

# %%
list = ["Afghanistan", "Asia", 4, 5, 1987, 6.2]

# %%
print(list)
# Out:
# ['Afghanistan', 'Asia', 4, 5, 1987, 6.2]

# %%
list[2]
# Out:
# 4

# %% [markdown]
# List is an ordered sequence of objects.

# %%
list[2:5]
# Out:
# [4, 5, 1987]

# %%
list[3] = 187.55

# %%
print(list)
# Out:
# ['Afghanistan', 'Asia', 4, 187.55, 1987, 6.2]

# %%
tuple = ("Afghanistan", "Asia", 4, 187.55, 1987, 6.2)

# %%
print(tuple)
# Out:
# ('Afghanistan', 'Asia', 4, 187.55, 1987, 6.2)

# %% [markdown]
# Tuples are ordered sequences of objects
# Tuples are indexed and the index begins from 0

# %%
tuple[0]
# Out:
# 'Afghanistan'

# %% [markdown]
# Unlike lists, tuples are not mutable. This means once you define the tuple, you can not change a value inside of the tuple like we did in the list.

# %%
dict = {1:"a", 2:"b", dna:"ATG"}
# key:value. Dictionaries are not indexed, so they require keys to call values. They are an unordered sequence of objects.

# %%
dict[dna]
# Out:
# 'ATG'

# %%
my_Order = {'menuItems':["Chicken", "Soup"], 'menuType':["Solid", "Liquid"], 'menuCost':[4.99, 2.99]}

# %%
print(my_Order)
# Out:
# {'menuItems': ['Chicken', 'Soup'], 'menuType': ['Solid', 'Liquid'], 'menuCost': [4.99, 2.99]}

# %%
import pandas as pd

# %% [markdown]
# This imports the file pandas to be called as pd. So to use any functions from pandas, you would type pd. EG: math.sqrt(), so the new example is pd.function()

# %%
My_Order = pd.DataFrame(data=my_Order)

# %%
print(My_Order)
# Out:
#    menuCost menuItems menuType
# 0      4.99   Chicken    Solid
# 1      2.99      Soup   Liquid

# %%
my_file = pd.read_table("gapminder.txt")

# %%
print(my_file)
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
my_file
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %% [markdown]
# The pandas library is how one imports a file into Python

# %%
# pd.read_excel("<path/to/the/file>")

# pd.read_csv("<path/to/the/file>")

# %%
# .iloc[] - integer based position indexing
# dataframe.iloc[row selection, column selection]

my_file.iloc[1, 5]
my_file.iloc[1:4, 2:5]
my_file.iloc[[0, 1, 5], [2, 5]]
# Out:
#    year   gdpPercap
# 0  1952  779.445314
# 1  1957  820.853030
# 5  1977  786.113360

# %%
# .loc[] - label based position indexing
# .loc[row selection, column selection]

my_file.loc[:, ['year']]

my_file.loc[:, ['year', 'continent']]

my_file.loc[1:2, ['year', 'continent']]
# Out:
#    year continent
# 1  1957      Asia
# 2  1962      Asia

# %%
# .loc[] - label based position indexing
# .loc[row selection, column selection]

my_file.loc[my_file['country']=='Afghanistan']
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338

# %%
ls = my_file['country']=="Afghanistan"

# %%
print(ls)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679    False
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691    False
# 1692    False
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698    False
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# ...

# %%
# This is LifeExpPlot.py

# importing packages

import pandas as pd
import matplotlib.pyplot as plt

# Reading file
my_file = pd.read_table("gapminder.txt")

#Subsetting Life Expectancy of Canada over a span of several years

Canada = my_file.loc[my_file['country'] == "Canada", :]

# Plotting
Canada.plot.line(x = "year", y = "lifeExp", label = "Life Expectancy", figsize = (8, 6))
plt.suptitle("Life Expectancy in Canada Over the Years", fontsize = 20)
plt.xlabel("Year", fontsize = 16)
plt.ylabel("Life Expectancy", fontsize = 16)
plt.show()

# %% [markdown]
# # This begins Challenge 3.1

# %%
# 1. Can you extract 3rd and 5th column of the dataset?

my_file.iloc[:, [2, 4]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# 5     1977  14880372
# 6     1982  12881816
# 7     1987  13867957
# 8     1992  16317921
# 9     1997  22227415
# 10    2002  25268405
# 11    2007  31889923
# 12    1952   1282697
# 13    1957   1476505
# 14    1962   1728137
# 15    1967   1984060
# 16    1972   2263554
# 17    1977   2509048
# 18    1982   2780097
# 19    1987   3075321
# 20    1992   3326498
# 21    1997   3428038
# 22    2002   3508512
# 23    2007   3600523
# 24    1952   9279525
# 25    1957  10270856
# 26    1962  11000948
# 27    1967  12760499
# 28    1972  14760787
# 29    1977  17152804
# ...    ...       ...
# 1674  1982   9657618
# 1675  1987  11219340
# 1676  1992  13367997
# 1677  1997  15826497
# 1678  2002  18701257
# 1679  2007  22211743
# 1680  1952   2672000
# 1681  1957   3016000
# 1682  1962   3421000
# 1683  1967   3900000
# 1684  1972   4506497
# ...

# %%
# 2. Can you extract the list of countries in this dataset?

df = pd.DataFrame(my_file.country.unique())

# %%
df
# Out:
#                             0
# 0                 Afghanistan
# 1                     Albania
# 2                     Algeria
# 3                      Angola
# 4                   Argentina
# 5                   Australia
# 6                     Austria
# 7                     Bahrain
# 8                  Bangladesh
# 9                     Belgium
# 10                      Benin
# 11                    Bolivia
# 12     Bosnia_and_Herzegovina
# 13                   Botswana
# 14                     Brazil
# 15                   Bulgaria
# 16               Burkina_Faso
# 17                    Burundi
# 18                   Cambodia
# 19                   Cameroon
# 20                     Canada
# 21   Central_African_Republic
# 22                       Chad
# 23                      Chile
# 24                      China
# 25                   Colombia
# 26                    Comoros
# 27              Congo_Dem_Rep
# 28                  Congo_Rep
# 29                 Costa_Rica
# ...

# %%
# 3. Can you get a part of this dataset that includes information about Sweden?

my_file.loc[my_file['country']=='Sweden']
# Out:
#      country continent  year  lifeExp      pop     gdpPercap
# 1464  Sweden    Europe  1952   71.860  7124673   8527.844662
# 1465  Sweden    Europe  1957   72.490  7363802   9911.878226
# 1466  Sweden    Europe  1962   73.370  7561588  12329.441920
# 1467  Sweden    Europe  1967   74.160  7867931  15258.296970
# 1468  Sweden    Europe  1972   74.720  8122293  17832.024640
# 1469  Sweden    Europe  1977   75.440  8251648  18855.725210
# 1470  Sweden    Europe  1982   76.420  8325260  20667.381250
# 1471  Sweden    Europe  1987   77.190  8421403  23586.929270
# 1472  Sweden    Europe  1992   78.160  8718867  23880.016830
# 1473  Sweden    Europe  1997   79.390  8897619  25266.594990
# 1474  Sweden    Europe  2002   80.040  8954175  29341.630930
# 1475  Sweden    Europe  2007   80.884  9031088  33859.748350

# %%
# 4. Can you extract all countries for which life expectancy is below 70?

my_file.loc[my_file['lifeExp']<70]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
# 5. Can you make a new column that contains population in units of millions of people?

my_file["popmil"] = pd.Series(my_file["pop"]/1000000)

# %%
my_file
# Out:
#           country continent  year  lifeExp       pop    gdpPercap     popmil
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314   8.425333
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030   9.240934
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710  10.267083
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138  11.537966
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106  13.079460
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360  14.880372
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439  12.881816
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945  13.867957
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395  16.317921
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351  22.227415
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055  25.268405
# ...

# %% [markdown]
# # This Begins Challenge 3.2

# %%
# Write your own python script Write a script to calculate mean gdpPerCap for African and European countries. Try to make a barplot to display your results.
# You might need to read help for ‘mean’ and ‘plot’ functions .mean() plt.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-d6f9fd3626d1> in <module>()
#       2 # You might need to read help for ‘mean’ and ‘plot’ functions .mean() plt.bar()
#       3
# ----> 4 help(pd.mean())
#
# AttributeError: module 'pandas' has no attribute 'mean'
